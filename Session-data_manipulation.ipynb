# %% [markdown]
# # Session: Data Manipulation
# ## Introduction
# We'll be using wine-reviews dataset for today's session.
#
# Let's have a look a our dataset

# %%
import pandas as pd

wine_reviews = pd.read_csv("/content/wine-dataset.csv", index_col=0)
pd.set_option("display.max_rows", 5)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_reviews.shape
# Out:
# (10336, 13)

# %% [markdown]
# # Checking and removing duplicates

# %%
wine_reviews.duplicated()
# Out:
# 0        False
# 1        False
#          ...
# 33606    False
# 33607    False
# Length: 33608, dtype: bool

# %%
duplicate_rows = wine_reviews.duplicated()

duplicate_rows.head(2409)
# Out:
# 0       False
# 1       False
#         ...
# 2407    False
# 2408     True
# Length: 2409, dtype: bool

# %%
wine_reviews[duplicate_rows]
# Out:
#         country                                        description  \
# 2408         US  This is weighty, creamy and medium to full in ...
# 2409      Italy  There's a touch of toasted almond at the start...
# ...         ...                                                ...
# 10148  Portugal  A surprisingly fresh wine for an Alvarinho fro...
# 10149  Portugal  This is an attractive, perfumed wine that is a...
#
#               designation  points  price           province     region_1  \
# 2408                  NaN      85   14.0         California  North Coast
# 2409   Sallier de la Tour      85   13.0  Sicily & Sardinia      Sicilia
# ...                   ...     ...    ...                ...          ...
# 10148       Terra d'Alter      87   14.0         Alentejano          NaN
# 10149       Terra d'Alter      87   10.0         Alentejano          NaN
#
#           region_2     taster_name taster_twitter_handle  \
# 2408   North Coast  Virginie Boone               @vboone
# 2409           NaN             NaN                   NaN
# ...            ...             ...                   ...
# 10148          NaN      Roger Voss            @vossroger
# 10149          NaN      Roger Voss            @vossroger
#
#                                                    title           variety  \
# 2408             Souverain 2010 Chardonnay (North Coast)        Chardonnay
# 2409   Tasca d'Almerita 2011 Sallier de la Tour Grill...            Grillo
# ...                                                  ...               ...
# 10148  Terras de Alter 2014 Terra d'Alter Alvarinho (...         Alvarinho
# 10149  Terras de Alter 2014 Terra d'Alter White (Alen...  Portuguese White
#
#                  winery
# 2408          Souverain
# 2409   Tasca d'Almerita
# ...                 ...
# 10148   Terras de Alter
# 10149   Terras de Alter
#
# [43 rows x 13 columns]

# %% [markdown]
# These are the duplicated rows.
# 43 duplicate rows.
#
# Now let's drop these rows

# %%
wine_reviews.drop_duplicates(inplace = True)
# inplace removes in same dataset

wine_reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 33606        US  This is soft, smooth and refined, with rich, c...
# 33607     Italy  Bosco Faiano is a hearty, masculine wine, aged...
#
#                     designation  points  price           province  \
# 0                  Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                      Avidagos      87   15.0              Douro
# ...                         ...     ...    ...                ...
# 33606  Estate Grown and Bottled      91   25.0         California
# 33607              Bosco Faiano      91   45.0              South
#
#                 region_1       region_2    taster_name taster_twitter_handle  \
# 0                   Etna            NaN  Kerin O’Keefe          @kerinokeefe
# 1                    NaN            NaN     Roger Voss            @vossroger
# ...                  ...            ...            ...                   ...
# 33606  Santa Ynez Valley  Central Coast            NaN                   NaN
# 33607                NaN            NaN            NaN                   NaN
#
#                                                    title         variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                  ...             ...
# 33606  Zaca Mesa 2009 Estate Grown and Bottled Syrah ...           Syrah
# 33607                                                NaN             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# ...                    ...
# 33606            Zaca Mesa
# 33607                  NaN
#
# [33005 rows x 13 columns]

# %%
wine_reviews.shape
# Out:
# (33005, 13)

# %% [markdown]
# # Dropping columns
# to remove unwanted features, which don't contribute to the data and might create noise.
#
# This helps in data cleaning

# %% [markdown]
# To check and review columns, let's use value_counts()

# %%
wine_reviews.taster_name
# Out:
# 0        Kerin O’Keefe
# 1           Roger Voss
#              ...
# 33606              NaN
# 33607              NaN
# Name: taster_name, Length: 33005, dtype: object

# %%
wine_reviews.taster_name.value_counts()
# Out:
# Roger Voss           2005
# Michael Schachner    1248
#                      ...
# Carrie Dykes            6
# Fiona Adams             3
# Name: taster_name, Length: 18, dtype: int64

# %%
#wine_reviews.points

wine_reviews.price
# Out:
# 0         NaN
# 1        15.0
#          ...
# 33606    25.0
# 33607    45.0
# Name: price, Length: 33005, dtype: float64

# %%
wine_reviews.title.value_counts()

#wine_reviews.designation.value_counts()
# Out:
# Korbel NV Brut Sparkling (California)                                4
# G. H. Mumm NV Brut Rosé  (Champagne)                                 3
#                                                                     ..
# Torii Mor 2013 Nysa Vineyard Pinot Noir (Dundee Hills)               1
# Zaca Mesa 2009 Estate Grown and Bottled Syrah (Santa Ynez Valley)    1
# Name: title, Length: 32916, dtype: int64

# %% [markdown]
# evidently, we don't need title column

# %%
wine_reviews.variety.value_counts()
# Out:
# Pinot Noir    3341
# Chardonnay    2879
#               ...
# Mavrud           1
# Mission          1
# Name: variety, Length: 498, dtype: int64

# %% [markdown]
# Let's select unwanted columns to remove:
#
#
# *   description
# *   region_2
# *   twitter_handle
# *   title

# %%
reviews = wine_reviews.drop(["description","region_2","taster_twitter_handle","title"], axis=1)

# or You can use inplace=True parameter

reviews
# Out:
#         country               designation  points  price           province  \
# 0         Italy              Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1      Portugal                  Avidagos      87   15.0              Douro
# ...         ...                       ...     ...    ...                ...
# 33606        US  Estate Grown and Bottled      91   25.0         California
# 33607     Italy              Bosco Faiano      91   45.0              South
#
#                 region_1    taster_name         variety               winery
# 0                   Etna  Kerin O’Keefe     White Blend              Nicosia
# 1                    NaN     Roger Voss  Portuguese Red  Quinta dos Avidagos
# ...                  ...            ...             ...                  ...
# 33606  Santa Ynez Valley            NaN           Syrah            Zaca Mesa
# 33607                NaN            NaN             NaN                  NaN
#
# [33005 rows x 9 columns]

# %%
wine_reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 33606        US  This is soft, smooth and refined, with rich, c...
# 33607     Italy  Bosco Faiano is a hearty, masculine wine, aged...
#
#                     designation  points  price           province  \
# 0                  Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                      Avidagos      87   15.0              Douro
# ...                         ...     ...    ...                ...
# 33606  Estate Grown and Bottled      91   25.0         California
# 33607              Bosco Faiano      91   45.0              South
#
#                 region_1       region_2    taster_name taster_twitter_handle  \
# 0                   Etna            NaN  Kerin O’Keefe          @kerinokeefe
# 1                    NaN            NaN     Roger Voss            @vossroger
# ...                  ...            ...            ...                   ...
# 33606  Santa Ynez Valley  Central Coast            NaN                   NaN
# 33607                NaN            NaN            NaN                   NaN
#
#                                                    title         variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                  ...             ...
# 33606  Zaca Mesa 2009 Estate Grown and Bottled Syrah ...           Syrah
# 33607                                                NaN             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# ...                    ...
# 33606            Zaca Mesa
# 33607                  NaN
#
# [33005 rows x 13 columns]

# %% [markdown]
# Initially there were 13 columns, out of which we've removed 4.

# %% [markdown]
# ## Removing NaN values
# It's a step in data cleaning process
#
# there are two ways to deal with NaN values
#
#
# 1.   removing the rows containing NaN
# 2.   replacing values with mean of that column

# %%
reviews.dropna()
# Out:
#          country                         designation  points  price  \
# 3             US                Reserve Late Harvest      87   13.0
# 4             US  Vintner's Reserve Wild Child Block      87   65.0
# ...          ...                                 ...     ...    ...
# 33602         US                               Naked      88   11.0
# 33605  Australia    George Wyndham Founder's Reserve      91   20.0
#
#               province              region_1         taster_name     variety  \
# 3             Michigan   Lake Michigan Shore  Alexander Peartree    Riesling
# 4               Oregon     Willamette Valley        Paul Gregutt  Pinot Noir
# ...                ...                   ...                 ...         ...
# 33602       Washington  Columbia Valley (WA)        Paul Gregutt  Chardonnay
# 33605  South Australia       Langhorne Creek      Joe Czerwinski      Shiraz
#
#                winery
# 3          St. Julian
# 4        Sweet Cheeks
# ...               ...
# 33602    Ryan Patrick
# 33605  Wyndham Estate
#
# [13595 rows x 9 columns]

# %% [markdown]
# Let's fill null values of points with their min

# %%
min_points= reviews.points.min()
min_points
# Out:
# 80

# %%
reviews[reviews.price.isnull()]
# Out:
#       country   designation  points  price           province  \
# 0       Italy  Vulkà Bianco      87    NaN  Sicily & Sardinia
# 13      Italy         Rosso      87    NaN  Sicily & Sardinia
# ...       ...           ...     ...    ...                ...
# 33586   Italy       Riserva      88    NaN            Tuscany
# 33598   Italy        Lamole      88    NaN            Tuscany
#
#                region_1    taster_name            variety  \
# 0                  Etna  Kerin O’Keefe        White Blend
# 13                 Etna  Kerin O’Keefe  Nerello Mascalese
# ...                 ...            ...                ...
# 33586    Chianti Rufina            NaN         Sangiovese
# 33598  Chianti Classico            NaN         Sangiovese
#
#                        winery
# 0                     Nicosia
# 13        Masseria Setteporte
# ...                       ...
# 33586        Villa Travignoli
# 33598  Castelli del Grevepesa
#
# [2349 rows x 9 columns]

# %%
reviews.points.fillna(80, inplace=True)

# %%
reviews
# Out:
#         country               designation  points  price           province  \
# 0         Italy              Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1      Portugal                  Avidagos      87   15.0              Douro
# ...         ...                       ...     ...    ...                ...
# 33606        US  Estate Grown and Bottled      91   25.0         California
# 33607     Italy              Bosco Faiano      91   45.0              South
#
#                 region_1    taster_name         variety               winery
# 0                   Etna  Kerin O’Keefe     White Blend              Nicosia
# 1                    NaN     Roger Voss  Portuguese Red  Quinta dos Avidagos
# ...                  ...            ...             ...                  ...
# 33606  Santa Ynez Valley            NaN           Syrah            Zaca Mesa
# 33607                NaN            NaN             NaN                  NaN
#
# [33005 rows x 9 columns]

# %%
reviews[reviews.points.isnull()]
# Out:
# Empty DataFrame
# Columns: [country, designation, points, price, province, region_1, taster_name, variety, winery]
# Index: []

# %% [markdown]
# Let's replace null values in price column with their average

# %%
avg = reviews.price.mean()
avg
# Out:
# 34.95570198329854

# %%
reviews.price.fillna(avg, inplace=True)

# %%
reviews[reviews.price.isnull()]
# Out:
# Empty DataFrame
# Columns: [country, designation, points, price, province, region_1, taster_name, variety, winery]
# Index: []

# %% [markdown]
# drop rows where there's no province

# %%
reviews.province.dropna()
# Out:
# 0        Sicily & Sardinia
# 3                 Michigan
#                ...
# 33602           Washington
# 33605      South Australia
# Name: province, Length: 14518, dtype: object

# %%
reviews[reviews.province.isnull()]
# Out:
# Empty DataFrame
# Columns: [country, designation, points, price, province, region_1, taster_name, variety, winery]
# Index: []

# %%
reviews.dropna(subset=['province', 'country'])
# Out:
#          country                       designation  points      price  \
# 0          Italy                      Vulkà Bianco      87  34.955702
# 3             US              Reserve Late Harvest      87  13.000000
# ...          ...                               ...     ...        ...
# 33602         US                             Naked      88  11.000000
# 33605  Australia  George Wyndham Founder's Reserve      91  20.000000
#
#                 province              region_1         taster_name  \
# 0      Sicily & Sardinia                  Etna       Kerin O’Keefe
# 3               Michigan   Lake Michigan Shore  Alexander Peartree
# ...                  ...                   ...                 ...
# 33602         Washington  Columbia Valley (WA)        Paul Gregutt
# 33605    South Australia       Langhorne Creek      Joe Czerwinski
#
#            variety          winery
# 0      White Blend         Nicosia
# 3         Riesling      St. Julian
# ...            ...             ...
# 33602   Chardonnay    Ryan Patrick
# 33605       Shiraz  Wyndham Estate
#
# [14518 rows x 9 columns]

# %% [markdown]
# ## drop the rows
#
# let's drop rows with NaN values

# %%
reviews.dropna(inplace=True)
reviews
# Out:
#          country                       designation  points      price  \
# 0          Italy                      Vulkà Bianco      87  34.955702
# 3             US              Reserve Late Harvest      87  13.000000
# ...          ...                               ...     ...        ...
# 33602         US                             Naked      88  11.000000
# 33605  Australia  George Wyndham Founder's Reserve      91  20.000000
#
#                 province              region_1         taster_name  \
# 0      Sicily & Sardinia                  Etna       Kerin O’Keefe
# 3               Michigan   Lake Michigan Shore  Alexander Peartree
# ...                  ...                   ...                 ...
# 33602         Washington  Columbia Valley (WA)        Paul Gregutt
# 33605    South Australia       Langhorne Creek      Joe Czerwinski
#
#            variety          winery
# 0      White Blend         Nicosia
# 3         Riesling      St. Julian
# ...            ...             ...
# 33602   Chardonnay    Ryan Patrick
# 33605       Shiraz  Wyndham Estate
#
# [14518 rows x 9 columns]

# %% [markdown]
# As you'll learn, we do this with the `groupby()` operation.  We'll also cover some additional topics, such as more complex ways to index your DataFrames, along with how to sort your data.
#
# # Groupwise analysis
#
# One function we've been using heavily thus far is the `value_counts()` function. We can replicate what `value_counts()` does by doing the following:

# %%
reviews.country.value_counts()
# Out:
# US           6494
# France       3583
#              ...
# Australia     356
# Canada         49
# Name: country, Length: 7, dtype: int64

# %%
reviews.groupby('country').price.mean()
# Out:
# country
# Argentina    26.125085
# Australia    39.709803
#                ...
# Spain        29.472186
# US           39.796363
# Name: price, Length: 7, dtype: float64

# %%
reviews.groupby('country').price.max()
# Out:
# country
# Argentina    215.0
# Australia    350.0
#              ...
# Spain        770.0
# US           625.0
# Name: price, Length: 7, dtype: float64

# %%
reviews[reviews.variety=='Riesling']
# Out:
#       country              designation  points  price  province  \
# 3          US     Reserve Late Harvest      87   13.0  Michigan
# 97         US           Ingle Vineyard      88   20.0  New York
# ...       ...                      ...     ...    ...       ...
# 33454  France       Réserve Saint Jean      88   17.0    Alsace
# 33483      US  Sawmill Creek Vineyards      87   17.0  New York
#
#                   region_1         taster_name   variety       winery
# 3      Lake Michigan Shore  Alexander Peartree  Riesling   St. Julian
# 97            Finger Lakes  Anna Lee C. Iijima  Riesling   Heron Hill
# ...                    ...                 ...       ...          ...
# 33454               Alsace    Anne Krebiehl MW  Riesling  Marcel Hugg
# 33483         Finger Lakes  Anna Lee C. Iijima  Riesling    Billsboro
#
# [487 rows x 9 columns]

# %%
reviews[reviews.country=='Argentina']
# Out:
#          country                       designation  points  price  \
# 16     Argentina                             Felix      87   30.0
# 17     Argentina               Winemaker Selection      87   13.0
# ...          ...                               ...     ...    ...
# 33379  Argentina                       Don Giaroli      81   14.0
# 33380  Argentina  Malbec-Merlot-Cabernet Sauvignon      81   19.0
#
#                province  region_1        taster_name  \
# 16                Other  Cafayate  Michael Schachner
# 17     Mendoza Province   Mendoza  Michael Schachner
# ...                 ...       ...                ...
# 33379  Mendoza Province   Mendoza  Michael Schachner
# 33380  Mendoza Province    Agrelo  Michael Schachner
#
#                         variety                   winery
# 16                       Malbec            Felix Lavaque
# 17                       Malbec            Gaucho Andino
# ...                         ...                      ...
# 33379                     Syrah  Hollen Family Vineyards
# 33380  Bordeaux-style Red Blend                 Trapezio
#
# [765 rows x 9 columns]

# %%
reviews.groupby('winery').points.mean()
# Out:
# winery
# 1+1=3           86.000
# 1000 Stories    91.000
#                  ...
# Öko             85.000
# àMaurice        89.125
# Name: points, Length: 5516, dtype: float64

# %%
reviews.groupby('winery').points.mean().sort_values()
# Out:
# winery
# Tenimenti Montagnana    80.0
# Baroncini               80.0
#                         ...
# Château Pontet-Canet    97.0
# Pirouette               98.0
# Name: points, Length: 5516, dtype: float64

# %%
reviews.head()
# Out:
#     country                         designation  points  price  \
# 0     Italy                        Vulkà Bianco      87    NaN
# 1  Portugal                            Avidagos      87   15.0
# 2        US                                 NaN      87   14.0
# 3        US                Reserve Late Harvest      87   13.0
# 4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#             province             region_1         taster_name         variety  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe     White Blend
# 1              Douro                  NaN          Roger Voss  Portuguese Red
# 2             Oregon    Willamette Valley        Paul Gregutt      Pinot Gris
# 3           Michigan  Lake Michigan Shore  Alexander Peartree        Riesling
# 4             Oregon    Willamette Valley        Paul Gregutt      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     18
# 81     53
#        ..
# 99      2
# 100     2
# Name: points, Length: 21, dtype: int64

# %%
reviews.points.value_counts()
# Out:
# 90     1926
# 88     1827
#        ...
# 98       10
# 100       1
# Name: points, Length: 20, dtype: int64

# %% [markdown]
# `groupby()` created a group of reviews which allotted the same point values to the given wines. Then, for each of these groups, we grabbed the `points()` column and counted how many times it appeared.  `value_counts()` is just a shortcut to this `groupby()` operation.
#
# We can use any of the summary functions we've used before with this data. For example, to get the cheapest wine in each point value category, we can do the following:

# %%
reviews.groupby('points').price.mean()
# Out:
# points
# 80      16.888889
# 81      19.865682
#           ...
# 98     190.100000
# 100    350.000000
# Name: price, Length: 20, dtype: float64

# %% [markdown]
# You can think of each group we generate as being a slice of our DataFrame containing only data with values that match. This DataFrame is accessible to us directly using the `apply()` method, and we can then manipulate the data in any way we see fit. For example, here's one way of selecting the name of the first wine reviewed from each winery in the dataset:

# %%
def show_min(arr):
  return arr.min()

show_avg = lambda arr: arr.mean()
# lambda func is a shorthand

# %%
arr1 = reviews.points

show_min(arr1)
# Out:
# 80

# %%
show_avg(reviews.points)
# Out:
# 88.89729990356798

# %%
wine_reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 10475, dtype: object

# %%
wine_reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %% [markdown]
# For even more fine-grained control, you can also group by more than one column. For an example, here's how we would pick out the best wine by country _and_ province:

# %%
reviews[reviews.country=='US']
# Out:
#       country                         designation  points  price    province  \
# 3          US                Reserve Late Harvest      87   13.0    Michigan
# 4          US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# ...       ...                                 ...     ...    ...         ...
# 33599      US                      Ingle Vineyard      88   15.0    New York
# 33602      US                               Naked      88   11.0  Washington
#
#                    region_1         taster_name         variety        winery
# 3       Lake Michigan Shore  Alexander Peartree        Riesling    St. Julian
# 4         Willamette Valley        Paul Gregutt      Pinot Noir  Sweet Cheeks
# ...                     ...                 ...             ...           ...
# 33599          Finger Lakes  Anna Lee C. Iijima  Cabernet Franc    Heron Hill
# 33602  Columbia Valley (WA)        Paul Gregutt      Chardonnay  Ryan Patrick
#
# [6494 rows x 9 columns]

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
#           Other                               Reserva      95   90.0
# ...                                               ...     ...    ...
# Uruguay   San Jose           El Preciado Gran Reserva      87   50.0
#           Uruguay           Blend 002 Limited Edition      91   22.0
#
#                                     province region_1 region_2  \
# country   province
# Argentina Mendoza Province  Mendoza Province  Mendoza      NaN
#           Other                        Other    Salta      NaN
# ...                                      ...      ...      ...
# Uruguay   San Jose                  San Jose      NaN      NaN
#           Uruguay                    Uruguay      NaN      NaN
#
#                                   taster_name taster_twitter_handle  \
# country   province
# Argentina Mendoza Province  Michael Schachner           @wineschach
#           Other             Michael Schachner           @wineschach
# ...                                       ...                   ...
# Uruguay   San Jose          Michael Schachner           @wineschach
#           Uruguay           Michael Schachner           @wineschach
#
#                                                                         title  \
# country   province
# Argentina Mendoza Province  Bodega Catena Zapata 2006 Nicasia Vineyard Mal...
#           Other                            Colomé 2010 Reserva Malbec (Salta)
# ...                                                                       ...
# Uruguay   San Jose          Castillo Viejo 2005 El Preciado Gran Reserva R...
#           Uruguay           Narbona NV Blend 002 Limited Edition Tannat-Ca...
#
#                                           variety                winery
# country   province
# Argentina Mendoza Province                 Malbec  Bodega Catena Zapata
#           Other                            Malbec                Colomé
# ...                                           ...                   ...
# Uruguay   San Jose                      Red Blend        Castillo Viejo
#           Uruguay           Tannat-Cabernet Franc               Narbona
#
# [425 rows x 13 columns]

# %% [markdown]
# Another `groupby()` method worth mentioning is `agg()`, which lets you run a bunch of different functions on your DataFrame simultaneously. For example, we can generate a simple statistical summary of the dataset as follows:

# %%
reviews.groupby('country').price.max()
# Out:
# country
# Argentina    215.0
# Australia    350.0
#              ...
# Spain        770.0
# US           625.0
# Name: price, Length: 7, dtype: float64

# %% [markdown]
# Aggregate method

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#             len  min    max
# country
# Argentina   765  4.0  215.0
# Australia   356  7.0  350.0
# ...         ...  ...    ...
# Spain      1333  4.0  770.0
# US         6494  5.0  625.0
#
# [7 rows x 3 columns]

# %% [markdown]
# Effective use of `groupby()` will allow you to do lots of really powerful things with your dataset.

# %% [markdown]
# # label encoding
#
# Data can't be fed to any model with string values in it
#
# The best way to deal with this is assigning a numerical value to the categorical values

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()

# Fit and transform the 'Category' column to get numerical labels
reviews['country'] = label_encoder.fit_transform(reviews['country'])

# %% [markdown]
# let's ahve look at new dataframe

# %%
reviews
# Out:
#        country                       designation  points      price  \
# 0            4                      Vulkà Bianco      87  34.955702
# 3            6              Reserve Late Harvest      87  13.000000
# ...        ...                               ...     ...        ...
# 33602        6                             Naked      88  11.000000
# 33605        1  George Wyndham Founder's Reserve      91  20.000000
#
#                 province              region_1         taster_name  \
# 0      Sicily & Sardinia                  Etna       Kerin O’Keefe
# 3               Michigan   Lake Michigan Shore  Alexander Peartree
# ...                  ...                   ...                 ...
# 33602         Washington  Columbia Valley (WA)        Paul Gregutt
# 33605    South Australia       Langhorne Creek      Joe Czerwinski
#
#            variety          winery
# 0      White Blend         Nicosia
# 3         Riesling      St. Julian
# ...            ...             ...
# 33602   Chardonnay    Ryan Patrick
# 33605       Shiraz  Wyndham Estate
#
# [14518 rows x 9 columns]

# %%
reviews.country
# Out:
# 0        4
# 3        6
#         ..
# 33602    6
# 33605    1
# Name: country, Length: 14518, dtype: int64

# %% [markdown]
# # Multi-indexes
#
# In all of the examples we've seen thus far we've been working with DataFrame or Series objects with a single-label index. `groupby()` is slightly different in the fact that, depending on the operation we run, it will sometimes result in what is called a multi-index.
#
# A multi-index differs from a regular index in that it has multiple levels. For example:

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# Multi-indices have several methods for dealing with their tiered structure which are absent for single-level indices. They also require two levels of labels to retrieve a value. Dealing with multi-index output is a common "gotcha" for users new to pandas.
#
# The use cases for a multi-index are detailed alongside instructions on using them in the [MultiIndex / Advanced Selection](https://pandas.pydata.org/pandas-docs/stable/advanced.html) section of the pandas documentation.
#
# However, in general the multi-index method you will use most often is the one for converting back to a regular index, the `reset_index()` method:

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# # Sorting

# %%
reviews
# Out:
#          country                       designation  points      price  \
# 0          Italy                      Vulkà Bianco      87  34.955702
# 3             US              Reserve Late Harvest      87  13.000000
# ...          ...                               ...     ...        ...
# 33602         US                             Naked      88  11.000000
# 33605  Australia  George Wyndham Founder's Reserve      91  20.000000
#
#                 province              region_1         taster_name  \
# 0      Sicily & Sardinia                  Etna       Kerin O’Keefe
# 3               Michigan   Lake Michigan Shore  Alexander Peartree
# ...                  ...                   ...                 ...
# 33602         Washington  Columbia Valley (WA)        Paul Gregutt
# 33605    South Australia       Langhorne Creek      Joe Czerwinski
#
#            variety          winery
# 0      White Blend         Nicosia
# 3         Riesling      St. Julian
# ...            ...             ...
# 33602   Chardonnay    Ryan Patrick
# 33605       Shiraz  Wyndham Estate
#
# [14518 rows x 9 columns]

# %%
reviews.sort_values(by='price')
# Out:
#          country    designation  points  price          province  \
# 1987       Spain    Flirty Bird      85    4.0     Central Spain
# 29553  Argentina            Red      84    4.0  Mendoza Province
# ...          ...            ...     ...    ...               ...
# 353       France  Le Montrachet      96  630.0          Burgundy
# 15846      Spain       El Perer      96  770.0         Catalonia
#
#                             region_1        taster_name       variety  \
# 1987   Vino de la Tierra de Castilla  Michael Schachner         Syrah
# 29553                        Mendoza  Michael Schachner  Malbec-Syrah
# ...                              ...                ...           ...
# 353                       Montrachet         Roger Voss    Chardonnay
# 15846                        Priorat  Michael Schachner      Carignan
#
#              winery
# 1987    Felix Solis
# 29553     Broke Ass
# ...             ...
# 353    Louis Latour
# 15846  Marco Abella
#
# [14518 rows x 9 columns]

# %%
reviews.sort_values(by='points')
# Out:
#          country               designation  points  price          province  \
# 7094   Argentina              Gran Reserva      80   18.0  Mendoza Province
# 19123     France  Vin de Pays de l'Ardeche      80   10.0      France Other
# ...          ...                       ...     ...    ...               ...
# 16772      Italy      Vigna Rionda Riserva      98  151.0          Piedmont
# 345    Australia                      Rare     100  350.0          Victoria
#
#          region_1        taster_name   variety                       winery
# 7094   Uco Valley  Michael Schachner    Malbec              Finca El Origen
# 19123      France  Michael Schachner  Viognier              Georges Duboeuf
# ...           ...                ...       ...                          ...
# 16772      Barolo      Kerin O’Keefe  Nebbiolo                    Massolino
# 345    Rutherglen     Joe Czerwinski    Muscat  Chambers Rosewood Vineyards
#
# [14518 rows x 9 columns]
